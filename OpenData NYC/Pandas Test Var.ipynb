# %%
import pandas as pd

# %%
cd OpenData NYC
# Out:
# [WinError 2] The system cannot find the file specified: 'OpenData NYC'
# C:\Users\Cameron Cowan\Jupyter Notebook\OpenData NYC

# %%
df = pd.read_csv("Value_of_Energy_Cost_Savings_Program_Formated.csv")
df
# Out:
#      Company ID                                       Company Name  \
# 0          3410                               139 ACA Realty, Inc.
# 1          3531        141 Lake Avenue Realty c/o JR Produce, Inc.
# 2          3465                             14-10 123rd Street LLC
# 3          3800                            183 Lorriane Street LLC
# 4          3482                          21st Century Optics, Inc.
# 5            19                         221 WEST 26TH STREET CORP.
# 6            20                             24-60 47TH STREET, LLC
# 7          3426                   2840 Atlantic Avenue Realty Corp
# 8            26                33RD STREET BAKERY INC. DBA PQ SOHO
# 9            41                                     4C FOODS CORP.
# 10         3422                                         4Over4.com
# 11         3461                               538-540 West 35 Corp
# 12         3539                             A & L Scientific Corp.
# ...

# %%
df['Savings from begining receiving benefits'].max()
# Out:
# ' $99,138.00 '

# %%
df['Company Name'][df['City']== 'Long Island City']
# Out:
# 0                                   139 ACA Realty, Inc.
# 8                    33RD STREET BAKERY INC. DBA PQ SOHO
# 10                                            4Over4.com
# 31                                  All City Metal, Inc.
# 35                                    ALRUE IMPORT COPR.
# 37                              American Folk Art Museum
# 41                                    AMY SCHERBER, INC.
# 45                     Applied Research & Consulting LLC
# 52                                           Artex, Inc.
# 56                                         AVI-SPL, Inc.
# 58                                  B. Thayer Associates
# 71                         Bermuda Motor Car REnting Co.
# 78                                 Big City Graphx, Inc.
# 82                                        BIMMY''''S LLC
# 83                                        BIMMY''''S LLC
# 92                               BoyceTechnologies, Inc.
# ...

# %%
df['Savings from begining receiving benefits'].min()
# Out:
# ' $1,079,560.02 '
